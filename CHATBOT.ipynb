# %% [markdown]
# <a href="https://colab.research.google.com/github/vishesh711/CHATBOT/blob/main/CHATBOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
intents_file = open('intents.json').read()
intents = json.loads(intents_file)

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        #add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list

        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['How', 'you', 'could', 'help', 'me', '?'], 'options'), (['What', 'you', 'can', 'do', '?'], 'options'), (['What', 'help', 'you', 'provide', '?'], 'options'), (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'), (['What', 'support', 'is', 'offered'], 'options'), (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'), (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'), (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug'), (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug'), (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug'), (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'), (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'), (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'), (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search'), (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'), (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'), (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search'), (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search'), (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'), (['Find', 'pharmacy'], 'pharmacy_search'), (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'), (['Locate', 'pharmacy'], 'pharmacy_search'), (['Search', 'pharmacy'], 'pharmacy_search'), (['Lookup', 'for', 'hospital'], 'hospital_search'), (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search'), (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'), (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'), (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatized words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
# Create the training data
training = []
# Create empty array for the output
output_empty = [0] * len(classes)

# Training set, bag of words for every sentence
for doc in documents:
    # Initializing bag of words
    bag = []
    # List of tokenized words for the pattern
    word_patterns = doc[0]
    # Lemmatize each word - create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
    # Output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# Shuffle the features
random.shuffle(training)

# Separate the features and labels
train_x = [elem[0] for elem in training]
train_y = [elem[1] for elem in training]

# Convert lists to NumPy arrays
train_x = np.array(train_x)
train_y = np.array(train_y)

print("Training data is created")
# Out:
# Training data is created

# %%
# Deep neural networks model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Training and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model is created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 1s 6ms/step - loss: 2.2357 - accuracy: 0.0638
# Epoch 2/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2083 - accuracy: 0.1915
# Epoch 3/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0581 - accuracy: 0.2128
# Epoch 4/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.9825 - accuracy: 0.2340
# Epoch 5/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9227 - accuracy: 0.3617
# Epoch 6/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7566 - accuracy: 0.3617
# Epoch 7/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6445 - accuracy: 0.5745
# Epoch 8/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.5478 - accuracy: 0.5319
# Epoch 9/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.4528 - accuracy: 0.5745
# Epoch 10/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1968 - accuracy: 0.6596
# Epoch 11/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2683 - accuracy: 0.6596
# Epoch 12/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9465 - accuracy: 0.7872
# Epoch 13/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9698 - accuracy: 0.7021
# Epoch 14/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9372 - accuracy: 0.6809
# Epoch 15/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8643 - accuracy: 0.7021
# Epoch 16/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7121 - accuracy: 0.8085
# Epoch 17/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7140 - accuracy: 0.7872
# Epoch 18/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6321 - accuracy: 0.7872
# Epoch 19/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6986 - accuracy: 0.7660
# Epoch 20/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6964 - accuracy: 0.8085
# Epoch 21/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4576 - accuracy: 0.8723
# Epoch 22/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4751 - accuracy: 0.9149
# Epoch 23/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4276 - accuracy: 0.9149
# Epoch 24/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4253 - accuracy: 0.8511
# Epoch 25/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3317 - accuracy: 0.8936
# Epoch 26/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3816 - accuracy: 0.9149
# Epoch 27/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3216 - accuracy: 0.9362
# Epoch 28/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2152 - accuracy: 0.9362
# Epoch 29/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4637 - accuracy: 0.8298
# Epoch 30/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3155 - accuracy: 0.9362
# Epoch 31/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2392 - accuracy: 0.9574
# Epoch 32/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1993 - accuracy: 0.9787
# Epoch 33/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3326 - accuracy: 0.9149
# Epoch 34/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3019 - accuracy: 0.8936
# Epoch 35/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2030 - accuracy: 0.9149
# Epoch 36/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2054 - accuracy: 0.9787
# Epoch 37/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2266 - accuracy: 0.9362
# Epoch 38/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1290 - accuracy: 0.9574
# Epoch 39/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2166 - accuracy: 0.9362
# Epoch 40/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2797 - accuracy: 0.9362
# Epoch 41/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1292 - accuracy: 0.9574
# Epoch 42/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1552 - accuracy: 0.9149
# Epoch 43/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0932 - accuracy: 0.9787
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 1.0000
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2039 - accuracy: 0.9574
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1545 - accuracy: 0.9574
# Epoch 47/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1666 - accuracy: 0.9787
# Epoch 48/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1024 - accuracy: 0.9574
# Epoch 49/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0754 - accuracy: 1.0000
# Epoch 50/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9787
# Epoch 51/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1092 - accuracy: 0.9787
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0838 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0889 - accuracy: 0.9787
# Epoch 54/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1637 - accuracy: 0.9149
# Epoch 55/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 0.9787
# Epoch 56/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1981 - accuracy: 0.9574
# Epoch 57/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1138 - accuracy: 0.9574
# Epoch 58/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0798 - accuracy: 1.0000
# Epoch 59/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1661 - accuracy: 0.9574
# Epoch 60/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0671 - accuracy: 0.9787
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0888 - accuracy: 0.9574
# Epoch 62/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0512 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0905 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9787
# Epoch 65/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1043 - accuracy: 0.9787
# Epoch 66/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1272 - accuracy: 0.9787
# Epoch 67/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1955 - accuracy: 0.9574
# Epoch 68/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0743 - accuracy: 1.0000
# Epoch 69/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0409 - accuracy: 0.9787
# Epoch 70/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0838 - accuracy: 0.9574
# Epoch 71/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0617 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0407 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0878 - accuracy: 0.9787
# Epoch 75/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0614 - accuracy: 0.9787
# Epoch 76/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0642 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0521 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0812 - accuracy: 0.9574
# Epoch 80/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0757 - accuracy: 0.9787
# Epoch 82/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0862 - accuracy: 0.9574
# Epoch 84/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0597 - accuracy: 0.9787
# Epoch 86/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0535 - accuracy: 0.9787
# Epoch 87/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0503 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9574
# Epoch 89/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0679 - accuracy: 0.9787
# Epoch 90/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0806 - accuracy: 0.9787
# Epoch 93/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0565 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9787
# Epoch 96/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0573 - accuracy: 0.9787
# Epoch 98/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0339 - accuracy: 0.9787
# Epoch 99/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1066 - accuracy: 0.9787
# Epoch 100/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9787
# Epoch 102/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0469 - accuracy: 0.9787
# Epoch 104/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0641 - accuracy: 0.9787
# Epoch 105/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0430 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0844 - accuracy: 0.9787
# Epoch 110/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0607 - accuracy: 0.9787
# Epoch 113/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0707 - accuracy: 0.9787
# Epoch 115/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0614 - accuracy: 0.9787
# Epoch 116/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0338 - accuracy: 0.9787
# Epoch 118/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0586 - accuracy: 0.9787
# Epoch 119/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0553 - accuracy: 0.9787
# Epoch 120/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0527 - accuracy: 0.9787
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 0.9787
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0337 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0435 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0892 - accuracy: 0.9574
# Epoch 133/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0374 - accuracy: 0.9787
# Epoch 142/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0599 - accuracy: 0.9787
# Epoch 145/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0400 - accuracy: 0.9787
# Epoch 147/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0983 - accuracy: 0.9787
# Epoch 148/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0395 - accuracy: 0.9787
# Epoch 153/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0642 - accuracy: 0.9787
# Epoch 159/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0860 - accuracy: 0.9787
# Epoch 162/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0927 - accuracy: 0.9574
# Epoch 165/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0681 - accuracy: 0.9574
# Epoch 167/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 0.9787
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0443 - accuracy: 0.9787
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0379 - accuracy: 0.9787
# Epoch 188/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0652 - accuracy: 0.9787
# Epoch 189/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 0.9787
# Epoch 195/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 1.0000
# model is created
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random

intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))

def clean_up_sentence(sentence):
    # tokenize the pattern - splitting words into array
    sentence_words = nltk.word_tokenize(sentence)
    # lemmatize every word - reducing to base form
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for words that exist in sentence
def bag_of_words(sentence, words, show_details=True):
    # tokenizing patterns
    sentence_words = clean_up_sentence(sentence)
    # bag of words - vocabulary matrix
    bag = [0] * len(words)
    for s in sentence_words:
        for i, word in enumerate(words):
            if word == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print("found in bag: %s" % word)
    return np.array(bag)

def predict_class(sentence):
    # filter below threshold predictions
    p = bag_of_words(sentence, words, show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
    # sorting strength probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if i['tag'] == tag:
            result = random.choice(i['responses'])
            break
    return result

# Command-line interface for the chatbot
print("Start chatting with the bot (type 'quit' to stop)!")
while True:
    message = input("You: ")
    if message.lower() == "quit":
        break

    ints = predict_class(message)
    res = getResponse(ints, intents)
    print("Bot:", res)
# Out:
# Start chatting with the bot (type 'quit' to stop)!
# You: hi
# 1/1 [==============================] - 0s 104ms/step
# Bot: Hi there, how can I help?
# You: i am good how are you?
# 1/1 [==============================] - 0s 19ms/step
# Bot: Good to see you again
# You: yup what all can you do?
# 1/1 [==============================] - 0s 22ms/step
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
# You: tell me about blood pressure
# 1/1 [==============================] - 0s 38ms/step
# Bot: Navigating to Blood Pressure module
# You: what is the normal blood pressure?
# 1/1 [==============================] - 0s 20ms/step
# Bot: Navigating to Blood Pressure module
# You: quit
